// %%
IO.println("Aqui...")
// Out:
// Aqui...

// %%
class Aula{
    int tempo;
    Aula(int tempo){
        this.tempo = tempo;
    }
    
    public String toString(){
        return "Aula "+tempo;
    }
}

new Aula(100);
// Out:
// Aula 100
