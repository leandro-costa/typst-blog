# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (3, 2)
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]
plt.plot(x, y);

# %%
len(x)

# %%
# | output: false
import sympy as sp
a, b = sp.symbols('a b')
sp.expand((a+b)**2)
